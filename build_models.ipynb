# %%
from pipelines.export_final import export_final_models
from pipelines.train_final import train_models

DATA_DIR = 'data/WESAD'

train_models(DATA_DIR)
export_final_models(DATA_DIR)
# Out:
# ...
# LOADING WESAD DATA
# ...
#
# data/WESAD\S10.pkl
# data/WESAD\S11.pkl
# data/WESAD\S13.pkl
# data/WESAD\S14.pkl
# data/WESAD\S15.pkl
# data/WESAD\S16.pkl
# data/WESAD\S17.pkl
# data/WESAD\S2.pkl
# data/WESAD\S3.pkl
# data/WESAD\S4.pkl
# data/WESAD\S5.pkl
# data/WESAD\S6.pkl
# data/WESAD\S7.pkl
# data/WESAD\S8.pkl
# data/WESAD\S9.pkl
# Loaded 15 subjects.
#
# ...
# TRAINING Logistic Regression
# ...
# Processing subject 15/15
# Dataset shape: (5701, 12)
# Labels shape: (5701,)
# Training Logistic Regression...
#
# Logistic Regression Accuracy: 0.6337
# Logistic Regression F1 Score: 0.5741
#               precision    recall  f1-score   support
#
#        Happy       0.63      0.89      0.74       611
#          Sad       0.62      0.55      0.58       282
#         Calm       0.71      0.14      0.23       159
#        Angry       0.00      0.00      0.00        89
#
#     accuracy                           0.63      1141
#    macro avg       0.49      0.40      0.39      1141
# ...
