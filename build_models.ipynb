# %%
from pipelines.export_final import export_final_models
from pipelines.train_final import train_models

DATA_DIR = 'data/WESAD'

train_models(DATA_DIR)
export_final_models(DATA_DIR)
# Out:
# ==========================================
# LOADING WESAD DATA
# ==========================================
#
# data/WESAD\S10.pkl
# data/WESAD\S11.pkl
# data/WESAD\S13.pkl
# data/WESAD\S14.pkl
# data/WESAD\S15.pkl
# data/WESAD\S16.pkl
# data/WESAD\S17.pkl
# data/WESAD\S2.pkl
# data/WESAD\S3.pkl
# data/WESAD\S4.pkl
# data/WESAD\S5.pkl
# data/WESAD\S6.pkl
# data/WESAD\S7.pkl
# data/WESAD\S8.pkl
# data/WESAD\S9.pkl
# Loaded 15 subjects.
#
# ==========================================
# TRAINING Logistic Regression
# ==========================================
# Processing subject 15/15
# Dataset shape: (5701, 12)
# Labels shape: (5701,)
# Training Logistic Regression...
#
# Logistic Regression Accuracy: 0.6337
# Logistic Regression F1 Score: 0.5741
#               precision    recall  f1-score   support
#
#     Baseline       0.63      0.89      0.74       611
#       Stress       0.62      0.55      0.58       282
#    Amusement       0.71      0.14      0.23       159
#   Meditation       0.00      0.00      0.00        89
#
#     accuracy                           0.63      1141
#    macro avg       0.49      0.40      0.39      1141
# weighted avg       0.59      0.63      0.57      1141
# Logistic Regression Results:
# Accuracy: 0.6337
# F1: 0.5741
#
# ==========================================
# TRAINING SVM
# ==========================================
# Processing subject 15/15
# Dataset shape: (5701, 26)
# Labels shape: (5701,)
# Training SVM...
#
# SVM Accuracy: 0.8081
# SVM F1 Score: 0.8018
#               precision    recall  f1-score   support
#
#     Baseline       0.80      0.90      0.85       611
#       Stress       0.76      0.80      0.78       282
#    Amusement       0.93      0.67      0.78       159
#   Meditation       0.85      0.44      0.58        89
#
#     accuracy                           0.81      1141
#    macro avg       0.84      0.70      0.75      1141
# weighted avg       0.82      0.81      0.80      1141
# SVM Results:
# Accuracy: 0.8081
# F1: 0.8018
#
# ==========================================
# TRAINING KNN
# ==========================================
# Processing subject 15/15
# Dataset shape: (5701, 20)
# Labels shape: (5701,)
# Training KNN...
#
# KNN Accuracy: 0.8457
# KNN F1 Score: 0.8455
#               precision    recall  f1-score   support
#
#     Baseline       0.87      0.87      0.87       611
#       Stress       0.80      0.85      0.82       282
#    Amusement       0.85      0.79      0.82       159
#   Meditation       0.87      0.74      0.80        89
#
#     accuracy                           0.85      1141
#    macro avg       0.84      0.81      0.83      1141
# weighted avg       0.85      0.85      0.85      1141
# KNN Results:
# Accuracy: 0.8457
# F1: 0.8455
#
# ==========================================
# TRAINING Random Forest
# ==========================================
# Processing subject 15/15
# Dataset shape: (5701, 32)
# Labels shape: (5701,)
# Training Random Forest...
#
# Random Forest Accuracy: 0.9632
# Random Forest F1 Score: 0.9629
#               precision    recall  f1-score   support
#
#     Baseline       0.96      0.98      0.97       611
#       Stress       0.96      0.98      0.97       282
#    Amusement       0.98      0.96      0.97       159
#   Meditation       0.99      0.84      0.91        89
#
#     accuracy                           0.96      1141
#    macro avg       0.97      0.94      0.95      1141
# weighted avg       0.96      0.96      0.96      1141
# Random Forest Results:
# Accuracy: 0.9632
# F1: 0.9629
#
# ==========================================
# TRAINING Gradient Boosting
# ==========================================
# Processing subject 15/15
# Dataset shape: (5701, 32)
# Labels shape: (5701,)
# Training Gradient Boosting...
#
# Gradient Boosting Accuracy: 0.9027
# Gradient Boosting F1 Score: 0.9013
#               precision    recall  f1-score   support
#
#     Baseline       0.90      0.94      0.92       611
#       Stress       0.89      0.90      0.90       282
#    Amusement       0.95      0.89      0.92       159
#   Meditation       0.92      0.67      0.78        89
#
#     accuracy                           0.90      1141
#    macro avg       0.91      0.85      0.88      1141
# weighted avg       0.90      0.90      0.90      1141
# Gradient Boosting Results:
# Accuracy: 0.9027
# F1: 0.9013
#
# ==========================================
# TRAINING XGBoost
# ==========================================
# Processing subject 15/15
# Dataset shape: (5701, 36)
# Labels shape: (5701,)
# Training XGBoost...
#
# XGBoost Accuracy: 0.9641
# XGBoost F1 Score: 0.9638
#               precision    recall  f1-score   support
#
#     Baseline       0.96      0.98      0.97       611
#       Stress       0.98      0.96      0.97       282
#    Amusement       0.96      0.98      0.97       159
#   Meditation       0.97      0.85      0.91        89
#
#     accuracy                           0.96      1141
#    macro avg       0.97      0.94      0.95      1141
# weighted avg       0.96      0.96      0.96      1141
# XGBoost Results:
# Accuracy: 0.9641
# F1: 0.9638
#
#
# ==========================================
# FINAL RESULTS
# ==========================================
#
# Logistic Regression   | Accuracy: 0.6337 | F1: 0.5741
# SVM                   | Accuracy: 0.8081 | F1: 0.8018
# KNN                   | Accuracy: 0.8457 | F1: 0.8455
# Random Forest         | Accuracy: 0.9632 | F1: 0.9629
# Gradient Boosting     | Accuracy: 0.9027 | F1: 0.9013
# XGBoost               | Accuracy: 0.9641 | F1: 0.9638
#
# ==========================================
#
# ==========================================
# FINAL MODEL EXPORT
# ==========================================
#
# Loading WESAD...
# data/WESAD\S10.pkl
# data/WESAD\S11.pkl
# data/WESAD\S13.pkl
# data/WESAD\S14.pkl
# data/WESAD\S15.pkl
# data/WESAD\S16.pkl
# data/WESAD\S17.pkl
# data/WESAD\S2.pkl
# data/WESAD\S3.pkl
# data/WESAD\S4.pkl
# data/WESAD\S5.pkl
# data/WESAD\S6.pkl
# data/WESAD\S7.pkl
# data/WESAD\S8.pkl
# data/WESAD\S9.pkl
# Loaded 15 subjects.
#
# ==========================================
# EXPORTING Logistic Regression
# ==========================================
# Processing subject 15/15
# Dataset shape: (5701, 12)
# Labels shape: (5701,)
#
# Training final Logistic Regression...
# Saved model:
#   models\logistic_regression.pkl
# Saved features:
#   models\logistic_regression_features.pkl
#
# ==========================================
# EXPORTING SVM
# ==========================================
# Processing subject 15/15
# Dataset shape: (5701, 26)
# Labels shape: (5701,)
#
# Training final SVM...
# Saved model:
#   models\svm.pkl
# Saved features:
#   models\svm_features.pkl
#
# ==========================================
# EXPORTING KNN
# ==========================================
# Processing subject 15/15
# Dataset shape: (5701, 20)
# Labels shape: (5701,)
#
# Training final KNN...
# Saved model:
#   models\knn.pkl
# Saved features:
#   models\knn_features.pkl
#
# ==========================================
# EXPORTING Random Forest
# ==========================================
# Processing subject 15/15
# Dataset shape: (5701, 32)
# Labels shape: (5701,)
#
# Training final Random Forest...
# Saved model:
#   models\random_forest.pkl
# Saved features:
#   models\random_forest_features.pkl
#
# ==========================================
# EXPORTING Gradient Boosting
# ==========================================
# Processing subject 15/15
# Dataset shape: (5701, 32)
# Labels shape: (5701,)
#
# Training final Gradient Boosting...
# Saved model:
#   models\gradient_boosting.pkl
# Saved features:
#   models\gradient_boosting_features.pkl
#
# ==========================================
# EXPORTING XGBoost
# ==========================================
# Processing subject 15/15
# Dataset shape: (5701, 36)
# Labels shape: (5701,)
#
# Training final XGBoost...
# Saved model:
#   models\xgboost.pkl
# Saved features:
#   models\xgboost_features.pkl
#
# Saved all feature information:
#   models\model_features.pkl
#
# Saved training metadata:
#   models\training_metadata.json
#
#
# ==========================================
# FINAL MODELS EXPORTED
# ==========================================
#
# Logistic Regression    → logistic_regression.pkl
# SVM                    → svm.pkl
# KNN                    → knn.pkl
# Random Forest          → random_forest.pkl
# Gradient Boosting      → gradient_boosting.pkl
# XGBoost                → xgboost.pkl
#
# ==========================================
# EXPORT COMPLETE
# ==========================================
# {'dataset': 'WESAD',
#  'models': {'Logistic Regression': {'model_file': 'logistic_regression.pkl',
#    'feature_file': 'logistic_regression_features.pkl',
#    'number_of_samples': 5701,
#    'number_of_features': 12,
#    'features': ['EDA Mean',
#     'EDA Std',
#     'EDA Min',
#     'EDA Max',
#     'BVP Mean',
#     'BVP Std',
#     'BVP Min',
#     'BVP Max',
#     'TEMP Mean',
#     'TEMP Std',
#     'TEMP Min',
#     'TEMP Max']},
#   'SVM': {'model_file': 'svm.pkl',
#    'feature_file': 'svm_features.pkl',
#    'number_of_samples': 5701,
#    'number_of_features': 26,
#    'features': ['EDA Mean',
#     'EDA Std',
#     'EDA Min',
#     'EDA Max',
#     'EDA Median',
#     'EDA Diff Mean',
#     'EDA Diff Std',
#     'EDA Peak Count',
#     'EDA Avg Peak Height',
#     'EDA Entropy',
#     'BVP Mean',
#     'BVP Std',
#     'BVP Skew',
#     'BVP Kurtosis',
#     'BVP FFT Mean',
#     'BVP FFT Std',
#     'BVP FFT Max',
#     'BVP Peak Count',
#     'BVP Diff Mean',
#     'BVP Diff Std',
#     'TEMP Mean',
#     'TEMP Std',
#     'TEMP Min',
#     'TEMP Max',
#     'TEMP Diff Mean',
#     'TEMP Diff Std']},
#   'KNN': {'model_file': 'knn.pkl',
#    'feature_file': 'knn_features.pkl',
#    'number_of_samples': 5701,
#    'number_of_features': 20,
#    'features': ['EDA Mean',
#     'EDA Std',
#     'EDA Min',
#     'EDA Max',
#     'EDA Median',
#     'EDA Diff Mean',
#     'EDA Diff Std',
#     'EDA Peak Count',
#     'EDA Avg Peak Height',
#     'EDA Entropy',
#     'BVP Mean',
#     'BVP Std',
#     'BVP Skew',
#     'BVP Kurtosis',
#     'BVP FFT Mean',
#     'BVP FFT Std',
#     'BVP FFT Max',
#     'BVP Peak Count',
#     'BVP Diff Mean',
#     'BVP Diff Std']},
#   'Random Forest': {'model_file': 'random_forest.pkl',
#    'feature_file': 'random_forest_features.pkl',
#    'number_of_samples': 5701,
#    'number_of_features': 32,
#    'features': ['EDA Mean',
#     'EDA Std',
#     'EDA Min',
#     'EDA Max',
#     'EDA Median',
#     'EDA Diff Mean',
#     'EDA Diff Std',
#     'EDA Peak Count',
#     'EDA Avg Peak Height',
#     'EDA Entropy',
#     'BVP Mean',
#     'BVP Std',
#     'BVP Skew',
#     'BVP Kurtosis',
#     'BVP FFT Mean',
#     'BVP FFT Std',
#     'BVP FFT Max',
#     'BVP Peak Count',
#     'BVP Diff Mean',
#     'BVP Diff Std',
#     'TEMP Mean',
#     'TEMP Std',
#     'TEMP Min',
#     'TEMP Max',
#     'TEMP Diff Mean',
#     'TEMP Diff Std',
#     'ACC Magnitude Mean',
#     'ACC Magnitude Std',
#     'ACC Magnitude Max',
#     'ACC Energy',
#     'ACC FFT Mean',
#     'ACC FFT Max']},
#   'Gradient Boosting': {'model_file': 'gradient_boosting.pkl',
#    'feature_file': 'gradient_boosting_features.pkl',
#    'number_of_samples': 5701,
#    'number_of_features': 32,
#    'features': ['EDA Mean',
#     'EDA Std',
#     'EDA Min',
#     'EDA Max',
#     'EDA Median',
#     'EDA Diff Mean',
#     'EDA Diff Std',
#     'EDA Peak Count',
#     'EDA Avg Peak Height',
#     'EDA Entropy',
#     'BVP Mean',
#     'BVP Std',
#     'BVP Skew',
#     'BVP Kurtosis',
#     'BVP FFT Mean',
#     'BVP FFT Std',
#     'BVP FFT Max',
#     'BVP Peak Count',
#     'BVP Diff Mean',
#     'BVP Diff Std',
#     'TEMP Mean',
#     'TEMP Std',
#     'TEMP Min',
#     'TEMP Max',
#     'TEMP Diff Mean',
#     'TEMP Diff Std',
#     'ACC Magnitude Mean',
#     'ACC Magnitude Std',
#     'ACC Magnitude Max',
#     'ACC Energy',
#     'ACC FFT Mean',
#     'ACC FFT Max']},
#   'XGBoost': {'model_file': 'xgboost.pkl',
#    'feature_file': 'xgboost_features.pkl',
#    'number_of_samples': 5701,
#    'number_of_features': 36,
#    'features': ['EDA Mean',
#     'EDA Std',
#     'EDA Min',
#     'EDA Max',
#     'EDA Median',
#     'EDA Diff Mean',
#     'EDA Diff Std',
#     'EDA Peak Count',
#     'EDA Avg Peak Height',
#     'EDA Entropy',
#     'BVP Mean',
#     'BVP Std',
#     'BVP Skew',
#     'BVP Kurtosis',
#     'BVP FFT Mean',
#     'BVP FFT Std',
#     'BVP FFT Max',
#     'BVP Peak Count',
#     'BVP Diff Mean',
#     'BVP Diff Std',
#     'TEMP Mean',
#     'TEMP Std',
#     'TEMP Min',
#     'TEMP Max',
#     'TEMP Diff Mean',
#     'TEMP Diff Std',
#     'ACC Magnitude Mean',
#     'ACC Magnitude Std',
#     'ACC Magnitude Max',
#     'ACC Energy',
#     'ACC FFT Mean',
#     'ACC FFT Max',
#     'EDA Global Skew',
#     'EDA Global Kurtosis',
#     'BVP Global Skew',
#     'BVP Global Kurtosis']}}}
